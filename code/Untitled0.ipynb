# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# 그래프에서 한글 깨짐 방지
import platform
plt.rc('font',family='Malgun Gothic')

# %%
# 코랩에서 그래프 한글 깨짐 방지
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 실행하고 런타임 다시 시작

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %%
df = pd.read_csv('/content/drive/MyDrive/ubion_finance/Datasets/피쳐선정전data.csv', index_col='Date', encoding='euc-kr')
df
# Out:
#          재고순환지표(%p)  경제심리지수  기계류내수출하지수(선박제외)(2020=100)   건설수주액(실질)(십억원)  \
# Date
# 2008-01         5.0   112.1                       98.5          10384.8
# 2008-02         3.9   112.0                       98.4           9246.1
# 2008-03         3.2   110.5                       98.4           9434.4
# 2008-04         0.4   109.4                       98.9          10121.7
# 2008-05        -1.6   106.1                       98.5           9955.6
# ...             ...     ...                        ...              ...
# 2022-12       -10.4    92.7                      115.4          10568.5
# 2023-01       -15.4    90.9                      111.2          13969.7
# 2023-02       -16.2    91.1                      106.9          14725.6
# 2023-03       -16.5    91.1                      101.0          14189.9
# 2023-04       -16.9    92.3                      101.5          10336.9
#
#          수출입물가비율(2015=100)  코스피(1980.1.4=100)   장단기금리차(%p)        외환보유액  \
# Date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 184 entries, 2008-01 to 2023-04
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   재고순환지표(%p)                 184 non-null    float64
#  1   경제심리지수                     184 non-null    float64
#  2   기계류내수출하지수(선박제외)(2020=100)  184 non-null    float64
#  3    건설수주액(실질)(십억원)            184 non-null    float64
#  4   수출입물가비율(2015=100)          184 non-null    float64
#  5   코스피(1980.1.4=100)          184 non-null    float64
#  6    장단기금리차(%p)                184 non-null    float64
#  7   외환보유액                      184 non-null    object
#  8   뉴스심리지수                     184 non-null    float64
#  9   원/달러                       184 non-null    float64
#  10  원/엔                        184 non-null    float64
#  11  원/위안                       184 non-null    float64
#  12  CD91일                      184 non-null    float64
# ...

# %%
df['외환보유액']=df['외환보유액'].apply(lambda x: x.replace(',','')).astype('float')

# %%
from statsmodels.tsa.stattools import grangercausalitytests
#df.replace(',', '', regex=True, inplace=True)
# a = df.apply(pd.to_numeric, errors='coerce') # numeric 변환
maxlag= 14
test = 'ssr_chi2test'

def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=True):

    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            # if verbose:print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            min_p_value_index = np.argmin(p_values)
            df.loc[r, c] = min_p_value
            print(r,c)
            print(f'Minimum P-value Index: {min_p_value_index} (Lag: {min_p_value_index + 1})')
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df
df=grangers_causation_matrix(df, variables = df.columns)
df
# Out:
# 재고순환지표(%p) 재고순환지표(%p)
# Minimum P-value Index: 0 (Lag: 1)
# 경제심리지수 재고순환지표(%p)
# Minimum P-value Index: 0 (Lag: 1)
# 기계류내수출하지수(선박제외)(2020=100) 재고순환지표(%p)
# Minimum P-value Index: 0 (Lag: 1)
#  건설수주액(실질)(십억원) 재고순환지표(%p)
# Minimum P-value Index: 1 (Lag: 2)
# 수출입물가비율(2015=100) 재고순환지표(%p)
# Minimum P-value Index: 0 (Lag: 1)
# 코스피(1980.1.4=100) 재고순환지표(%p)
# Minimum P-value Index: 0 (Lag: 1)
#  장단기금리차(%p) 재고순환지표(%p)
# Minimum P-value Index: 11 (Lag: 12)
# 외환보유액 재고순환지표(%p)
# Minimum P-value Index: 0 (Lag: 1)
# 뉴스심리지수 재고순환지표(%p)
# Minimum P-value Index: 0 (Lag: 1)
# 원/달러 재고순환지표(%p)
# Minimum P-value Index: 2 (Lag: 3)
# 원/엔 재고순환지표(%p)
# Minimum P-value Index: 1 (Lag: 2)
# 원/위안 재고순환지표(%p)
# Minimum P-value Index: 2 (Lag: 3)
# CD91일 재고순환지표(%p)
# Minimum P-value Index: 10 (Lag: 11)
# WTI유 재고순환지표(%p)
# Minimum P-value Index: 11 (Lag: 12)
# G7 재고순환지표(%p)
# Minimum P-value Index: 0 (Lag: 1)
# G20 재고순환지표(%p)
# Minimum P-value Index: 3 (Lag: 4)
# 미장단기 재고순환지표(%p)
# Minimum P-value Index: 0 (Lag: 1)
# ...

# %%
df.columns
# Out:
# Index(['재고순환지표(%p)_x', '경제심리지수_x', '기계류내수출하지수(선박제외)(2020=100)_x',
#        ' 건설수주액(실질)(십억원)_x', '수출입물가비율(2015=100)_x', '코스피(1980.1.4=100)_x',
#        ' 장단기금리차(%p)_x', '외환보유액_x', '뉴스심리지수_x', '원/달러_x', '원/엔_x', '원/위안_x',
#        'CD91일_x', 'WTI유_x', 'G7_x', 'G20_x', '미장단기_x', '거래량_x', '종가_x', '구리_x',
#        '천연가스_x', '은_x', '금_x'],
#       dtype='object')

# %%
# 0.05
# - 종가가 영향을 주는 것.
# 재고순환지표, 경제심리지수, 기계류내수출하지수, 수출입물가비율, 코스피, 장단기금리차, 원/달러, cd91일, wti, 미장단기, 거래량, 구리, 금
# - 종가가 영향을 받는 것
# 경제심리지수, 건설수주액, 수출입물가, 코스피, 장단기금리차, 외환보유, 뉴스, 원/달러, 원/엔, g7, g20, 미장단기, 구리, 천연가스, 은

# => 경제심리지수, 수출입물가비율, 코스피, 장단기금리차, 원/달러, 미장단기, 구리

# 0.01
# - 종가가 영향을 주는 것.
# 재고순환지표, 기계류내수출하지수, 코스피, 장단기금리차, cd91일, 거래량, 구리
# - 종가가 영향을 받는 것
# 경제심리지수, 수출입물가, 코스피, 외환보유, 뉴스, g7, g20, 은

# => 코스피
