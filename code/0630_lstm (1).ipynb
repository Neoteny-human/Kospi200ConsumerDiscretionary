# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = '{:.6f}'.format

# 그래프에서 한글 깨짐 방지
import platform
if platform.system() == "Darwin":          # MAC인 경우
    plt.rc('font', family ="AppleGothic")
else:
    plt.rc('font',family='Malgun Gothic')

#멧플로립에서 음수를 표시
plt.rc('axes',unicode_minus=False)

#워닝 메시지
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## 1.스케일링(standard_scale)

# %%
# 데이터 불러오기
df = pd.read_csv('/content/drive/MyDrive/newnew_data.csv')
df['Date'] = pd.to_datetime(df['Date'])  # 'Date' 열을 datetime 객체로 변환
df.set_index('Date', inplace=True)

df=df.drop(['원위안', '유가', '은', '외환보유액','구리'],axis=1) # G7 이미 삭제된 데이터셋
dataset =df.values
# dataset=df[['재고순환지표','경제심리지수','수출입물가비율','코스피','장단기','원달러','CD','G20','종가']].values
scaler=StandardScaler()
dataset= scaler.fit_transform(dataset)
print(dataset)
# Out:
# [[ 0.93589755  1.43327182 -0.74157178 ...  2.07114449 -1.74913464
#   -1.49457805]
#  [ 0.80523213  1.42294476 -0.75485022 ...  2.01342627 -1.57284691
#   -1.75012721]
#  [ 0.7220814   1.26803893 -0.75485022 ...  2.85611229 -1.33988349
#   -1.81061445]
#  ...
#  [-1.58238152 -0.73540982  0.37381684 ... -0.75285063  1.76937084
#   -0.3938106 ]
#  [-1.61801754 -0.73540982 -0.40961088 ... -0.59701144  1.4817088
#   -0.27075728]
#  [-1.66553224 -0.61148516 -0.3432187  ... -0.94751845  1.95422583
#   -0.27316174]]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# - scaled_df : 5개의 feature 삭제하고 남은 전체 데이터프레임
# - feature_df : scaled_df중 종가를 제외한 부분
# - label_df : scaled_df의 종가 부분

# %%
scaled_df = pd.DataFrame(dataset, columns=df.columns,index=df.index)
feature_df = scaled_df[['재고순환지표', '경제심리지수', '기계류내수출', '건설수주액', '수출입물가비율', '코스피', '장단기', '뉴스심리지수', '원달러', '원엔', 'CD', 'G20', '미장단기', '거래량', '천연가스', '금','종가']]
label_df = scaled_df['종가']

# %% [markdown]
# #### 사용한 데이터 :  내생 변수 -> 9개

# %%
feature_df_2 = feature_df[['재고순환지표','경제심리지수','수출입물가비율','코스피','장단기','원달러','CD','G20','종가']]

# %% [markdown]
# ## 2.tesnorflow에 사용될 데이터로 전처리

# %% [markdown]
# ### 데이터프레임을 --> array형태로

# %%
feature_np = feature_df_2.to_numpy()
label_np = label_df.to_numpy()

# %%
feature_np.shape
# Out:
# (184, 9)

# %% [markdown]
# ### tensorflow에서 사용하기 위한 데이터 형태 만들기
#     - feature : 학습시킬 데이터
#     - label : 예측할 데이터
#     - window_size : 몇개 전 데이터로 다음값을 예측할 것인지
#     - return: (row 총 개수 - windows , window_size , feature 개수) , (row 총 개수 - windows, )

# %% [markdown]
# #### 1. window로 3차원 텐서로 만들기

# %%
def make_sequence_dataset(feature, label, window_size):
  feature_list = []
  label_list = []

  for i in range(len(feature)-window_size):
    feature_list.append(feature[i:i+window_size])
    label_list.append(label[i+window_size-1])

  return np.array(feature_list), np.array(label_list) # 3차원 텐서

# %%
window_size=2
X, Y = make_sequence_dataset(feature_np, label_np, window_size) # batchsize, time steps ,input dims
print(X.shape,Y.shape)
# Out:
# (182, 2, 9) (182,)

# %% [markdown]
# #### 2. train,test으로 데이터 분할
#     - split : 테스트 개수

# %%
split = -36
x_train = X[0:split]
y_train = Y[0:split]

x_test = X[split:]
y_test = Y[split:]

print(x_train.shape, y_train.shape,x_test.shape, y_test.shape)
# Out:
# (146, 2, 9) (146,) (36, 2, 9) (36,)

# %% [markdown]
# ## 3. LSTM 모델링

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.utils import get_custom_objects

def prelu_activation(x):
    alpha = tf.constant(0.1)  # P-ReLU 매개변수
    return tf.keras.activations.relu(x) - alpha * tf.keras.activations.relu(-x)

get_custom_objects().update({'prelu_activation': prelu_activation})


def e_relu_activation(x):
    alpha = tf.constant(1.0)  # e-ReLU 매개변수
    return tf.keras.activations.relu(x) - alpha * (tf.exp(x) - 1)

get_custom_objects().update({'e_relu_activation': e_relu_activation})


# LSTM 모델 생성
from keras.layers import Bidirectional

model = Sequential()
model.add(Bidirectional(LSTM(256, return_sequences=True, dropout=0.18,recurrent_dropout =0.15,activation='e_relu_activation'), input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Bidirectional(LSTM(128, return_sequences=True, dropout=0.18, recurrent_dropout=0.15,activation='tanh')))
model.add(Bidirectional(LSTM(128, return_sequences=False, dropout=0.18, recurrent_dropout=0.15,activation='e_relu_activation')))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 2, 512)           544768
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 2, 256)           656384
#  nal)
#
#  bidirectional_2 (Bidirectio  (None, 256)              394240
#  nal)
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 1,595,649
# Trainable params: 1,595,649
# Non-trainable params: 0
# _________________________________________________________________

# %%
# early_stop = EarlyStopping(monitor='val_loss', patience=5)
model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=130, batch_size=6, verbose=1)
# Out:
# Epoch 1/130
# 25/25 [==============================] - 25s 207ms/step - loss: 1.1332 - val_loss: 0.4419
# Epoch 2/130
# 25/25 [==============================] - 2s 85ms/step - loss: 1.0498 - val_loss: 0.3997
# Epoch 3/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.7766 - val_loss: 0.3921
# Epoch 4/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.6641 - val_loss: 0.3350
# Epoch 5/130
# 25/25 [==============================] - 3s 104ms/step - loss: 0.5898 - val_loss: 0.3013
# Epoch 6/130
# 25/25 [==============================] - 4s 177ms/step - loss: 0.5454 - val_loss: 0.2596
# Epoch 7/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.5242 - val_loss: 0.2452
# Epoch 8/130
# 25/25 [==============================] - 2s 86ms/step - loss: 0.5004 - val_loss: 0.2153
# Epoch 9/130
# 25/25 [==============================] - 2s 89ms/step - loss: 0.4082 - val_loss: 0.1622
# Epoch 10/130
# 25/25 [==============================] - 2s 85ms/step - loss: 0.2408 - val_loss: 0.1473
# Epoch 11/130
# 25/25 [==============================] - 4s 177ms/step - loss: 0.1331 - val_loss: 0.1311
# Epoch 12/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.1071 - val_loss: 0.1173
# Epoch 13/130
# 25/25 [==============================] - 2s 91ms/step - loss: 0.0886 - val_loss: 0.0984
# Epoch 14/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0819 - val_loss: 0.0775
# Epoch 15/130
# 25/25 [==============================] - 2s 87ms/step - loss: 0.0798 - val_loss: 0.0877
# Epoch 16/130
# 25/25 [==============================] - 4s 168ms/step - loss: 0.0728 - val_loss: 0.0715
# Epoch 17/130
# 25/25 [==============================] - 4s 133ms/step - loss: 0.0673 - val_loss: 0.0646
# Epoch 18/130
# 25/25 [==============================] - 2s 87ms/step - loss: 0.0540 - val_loss: 0.1050
# Epoch 19/130
# 25/25 [==============================] - 2s 86ms/step - loss: 0.0518 - val_loss: 0.1079
# Epoch 20/130
# 25/25 [==============================] - 3s 116ms/step - loss: 0.0409 - val_loss: 0.1269
# Epoch 21/130
# 25/25 [==============================] - 4s 160ms/step - loss: 0.0363 - val_loss: 0.1040
# Epoch 22/130
# 25/25 [==============================] - 3s 99ms/step - loss: 0.0385 - val_loss: 0.1005
# Epoch 23/130
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0375 - val_loss: 0.1139
# Epoch 24/130
# 25/25 [==============================] - 2s 88ms/step - loss: 0.0360 - val_loss: 0.1181
# Epoch 25/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0404 - val_loss: 0.1342
# Epoch 26/130
# 25/25 [==============================] - 2s 100ms/step - loss: 0.0355 - val_loss: 0.1072
# Epoch 27/130
# 25/25 [==============================] - 5s 207ms/step - loss: 0.0362 - val_loss: 0.0928
# Epoch 28/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0407 - val_loss: 0.1218
# Epoch 29/130
# 25/25 [==============================] - 2s 87ms/step - loss: 0.0302 - val_loss: 0.0806
# Epoch 30/130
# 25/25 [==============================] - 2s 85ms/step - loss: 0.0323 - val_loss: 0.1137
# Epoch 31/130
# 25/25 [==============================] - 2s 91ms/step - loss: 0.0364 - val_loss: 0.0834
# Epoch 32/130
# 25/25 [==============================] - 4s 166ms/step - loss: 0.0396 - val_loss: 0.1010
# Epoch 33/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0344 - val_loss: 0.0914
# Epoch 34/130
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0377 - val_loss: 0.0792
# Epoch 35/130
# 25/25 [==============================] - 2s 90ms/step - loss: 0.0293 - val_loss: 0.0732
# Epoch 36/130
# 25/25 [==============================] - 2s 87ms/step - loss: 0.0352 - val_loss: 0.0932
# Epoch 37/130
# 25/25 [==============================] - 3s 133ms/step - loss: 0.0293 - val_loss: 0.0818
# Epoch 38/130
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0338 - val_loss: 0.0868
# Epoch 39/130
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0357 - val_loss: 0.0634
# Epoch 40/130
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0338 - val_loss: 0.0738
# Epoch 41/130
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0277 - val_loss: 0.0705
# Epoch 42/130
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0221 - val_loss: 0.0837
# Epoch 43/130
# 25/25 [==============================] - 4s 154ms/step - loss: 0.0257 - val_loss: 0.0938
# Epoch 44/130
# 25/25 [==============================] - 2s 96ms/step - loss: 0.0301 - val_loss: 0.0672
# Epoch 45/130
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0323 - val_loss: 0.0755
# Epoch 46/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0260 - val_loss: 0.0614
# Epoch 47/130
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0380 - val_loss: 0.0646
# Epoch 48/130
# 25/25 [==============================] - 2s 85ms/step - loss: 0.0306 - val_loss: 0.0655
# Epoch 49/130
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0259 - val_loss: 0.0574
# Epoch 50/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0280 - val_loss: 0.0719
# Epoch 51/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0327 - val_loss: 0.0710
# Epoch 52/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0278 - val_loss: 0.0701
# Epoch 53/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0269 - val_loss: 0.0645
# Epoch 54/130
# 25/25 [==============================] - 3s 112ms/step - loss: 0.0261 - val_loss: 0.0666
# Epoch 55/130
# 25/25 [==============================] - 3s 137ms/step - loss: 0.0218 - val_loss: 0.0757
# Epoch 56/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0247 - val_loss: 0.0646
# Epoch 57/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0285 - val_loss: 0.0750
# Epoch 58/130
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0274 - val_loss: 0.0806
# Epoch 59/130
# 25/25 [==============================] - 2s 85ms/step - loss: 0.0234 - val_loss: 0.0608
# Epoch 60/130
# 25/25 [==============================] - 4s 149ms/step - loss: 0.0314 - val_loss: 0.0625
# Epoch 61/130
# 25/25 [==============================] - 3s 106ms/step - loss: 0.0267 - val_loss: 0.0696
# Epoch 62/130
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0271 - val_loss: 0.0718
# Epoch 63/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0220 - val_loss: 0.0629
# Epoch 64/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0312 - val_loss: 0.0679
# Epoch 65/130
# 25/25 [==============================] - 2s 86ms/step - loss: 0.0290 - val_loss: 0.0589
# Epoch 66/130
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0207 - val_loss: 0.0740
# Epoch 67/130
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0233 - val_loss: 0.0608
# Epoch 68/130
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0221 - val_loss: 0.0691
# Epoch 69/130
# 25/25 [==============================] - 2s 86ms/step - loss: 0.0232 - val_loss: 0.0609
# Epoch 70/130
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0228 - val_loss: 0.0627
# Epoch 71/130
# 25/25 [==============================] - 3s 104ms/step - loss: 0.0259 - val_loss: 0.0773
# Epoch 72/130
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0259 - val_loss: 0.0848
# Epoch 73/130
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0332 - val_loss: 0.0980
# Epoch 74/130
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0190 - val_loss: 0.0820
# Epoch 75/130
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0229 - val_loss: 0.0677
# Epoch 76/130
# 25/25 [==============================] - 2s 87ms/step - loss: 0.0176 - val_loss: 0.0662
# Epoch 77/130
# 25/25 [==============================] - 3s 132ms/step - loss: 0.0202 - val_loss: 0.0698
# Epoch 78/130
# 25/25 [==============================] - 3s 120ms/step - loss: 0.0189 - val_loss: 0.0670
# Epoch 79/130
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0175 - val_loss: 0.0602
# Epoch 80/130
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0203 - val_loss: 0.0664
# Epoch 81/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0159 - val_loss: 0.0573
# Epoch 82/130
# 25/25 [==============================] - 2s 85ms/step - loss: 0.0210 - val_loss: 0.0741
# Epoch 83/130
# 25/25 [==============================] - 4s 169ms/step - loss: 0.0248 - val_loss: 0.0615
# Epoch 84/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0197 - val_loss: 0.0661
# Epoch 85/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0198 - val_loss: 0.0580
# Epoch 86/130
# 25/25 [==============================] - 2s 85ms/step - loss: 0.0179 - val_loss: 0.0673
# Epoch 87/130
# 25/25 [==============================] - 2s 85ms/step - loss: 0.0188 - val_loss: 0.0600
# Epoch 88/130
# 25/25 [==============================] - 2s 90ms/step - loss: 0.0191 - val_loss: 0.0684
# Epoch 89/130
# 25/25 [==============================] - 4s 161ms/step - loss: 0.0214 - val_loss: 0.0566
# Epoch 90/130
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0183 - val_loss: 0.0589
# Epoch 91/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0207 - val_loss: 0.0646
# Epoch 92/130
# 25/25 [==============================] - 2s 85ms/step - loss: 0.0190 - val_loss: 0.0609
# Epoch 93/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0178 - val_loss: 0.0667
# Epoch 94/130
# 25/25 [==============================] - 3s 129ms/step - loss: 0.0235 - val_loss: 0.0661
# Epoch 95/130
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0277 - val_loss: 0.0904
# Epoch 96/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0244 - val_loss: 0.0601
# Epoch 97/130
# 25/25 [==============================] - 2s 90ms/step - loss: 0.0156 - val_loss: 0.0641
# Epoch 98/130
# 25/25 [==============================] - 2s 86ms/step - loss: 0.0237 - val_loss: 0.0756
# Epoch 99/130
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0208 - val_loss: 0.0587
# Epoch 100/130
# 25/25 [==============================] - 4s 161ms/step - loss: 0.0167 - val_loss: 0.0739
# Epoch 101/130
# 25/25 [==============================] - 2s 85ms/step - loss: 0.0174 - val_loss: 0.0578
# Epoch 102/130
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0172 - val_loss: 0.0645
# Epoch 103/130
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0195 - val_loss: 0.0559
# Epoch 104/130
# 25/25 [==============================] - 2s 86ms/step - loss: 0.0224 - val_loss: 0.0526
# Epoch 105/130
# 25/25 [==============================] - 2s 86ms/step - loss: 0.0164 - val_loss: 0.0580
# Epoch 106/130
# 25/25 [==============================] - 4s 166ms/step - loss: 0.0185 - val_loss: 0.0577
# Epoch 107/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0177 - val_loss: 0.0488
# Epoch 108/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0181 - val_loss: 0.0610
# Epoch 109/130
# 25/25 [==============================] - 2s 86ms/step - loss: 0.0230 - val_loss: 0.0620
# Epoch 110/130
# 25/25 [==============================] - 2s 87ms/step - loss: 0.0199 - val_loss: 0.0684
# Epoch 111/130
# 25/25 [==============================] - 3s 121ms/step - loss: 0.0144 - val_loss: 0.0560
# Epoch 112/130
# 25/25 [==============================] - 3s 137ms/step - loss: 0.0178 - val_loss: 0.0506
# Epoch 113/130
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0187 - val_loss: 0.0486
# Epoch 114/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0197 - val_loss: 0.0542
# Epoch 115/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0165 - val_loss: 0.0479
# Epoch 116/130
# 25/25 [==============================] - 2s 82ms/step - loss: 0.0157 - val_loss: 0.0718
# Epoch 117/130
# 25/25 [==============================] - 4s 152ms/step - loss: 0.0164 - val_loss: 0.0542
# Epoch 118/130
# 25/25 [==============================] - 3s 104ms/step - loss: 0.0219 - val_loss: 0.0537
# Epoch 119/130
# 25/25 [==============================] - 2s 89ms/step - loss: 0.0165 - val_loss: 0.0406
# Epoch 120/130
# 25/25 [==============================] - 2s 87ms/step - loss: 0.0192 - val_loss: 0.0422
# Epoch 121/130
# 25/25 [==============================] - 2s 86ms/step - loss: 0.0188 - val_loss: 0.0489
# Epoch 122/130
# 25/25 [==============================] - 3s 102ms/step - loss: 0.0187 - val_loss: 0.0585
# Epoch 123/130
# 25/25 [==============================] - 4s 160ms/step - loss: 0.0211 - val_loss: 0.0576
# Epoch 124/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0183 - val_loss: 0.0605
# Epoch 125/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0164 - val_loss: 0.0461
# Epoch 126/130
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0169 - val_loss: 0.0402
# Epoch 127/130
# 25/25 [==============================] - 2s 84ms/step - loss: 0.0181 - val_loss: 0.0665
# Epoch 128/130
# 25/25 [==============================] - 3s 131ms/step - loss: 0.0136 - val_loss: 0.0488
# Epoch 129/130
# 25/25 [==============================] - 3s 123ms/step - loss: 0.0203 - val_loss: 0.0543
# Epoch 130/130
# 25/25 [==============================] - 2s 83ms/step - loss: 0.0146 - val_loss: 0.0385

# %% [markdown]
# ## 4.예측 및 시각화

# %%
# 예측
val_predict = model.predict(x_test)

# 역 변환기
scaler_y = StandardScaler()
scaled_data_y = scaler_y.fit_transform(df.iloc[:, -1].values.reshape(-1,1))

# 예측 값 스케일 역변환
val_predict = scaler_y.inverse_transform(val_predict)

# 실제 값 스케일 역변환
y_train = scaler_y.inverse_transform(y_train.reshape(-1,1))
y_test = scaler_y.inverse_transform(y_test.reshape(-1,1))

plt.figure(figsize=(10,6))
# Add the training set to the plot:
plt.plot(y_train, color='green', label='Train')
# Plot the test and prediction data:
plt.plot(range(len(y_train), len(y_train)+len(y_test)), y_test, color='blue', label='Real')
plt.plot(range(len(y_train), len(y_train)+len(y_test)), val_predict, color='red', label='Prediction')
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 1s 11ms/step
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.

# %%
print(len(val_predict))
# Out:
# 36

# %%
# 예측

plt.figure(figsize=(7,4))
plt.title('예측, window_size=2')
plt.ylabel('price(won)')
plt.xlabel('period(month)')
plt.grid()
plt.plot(val_predict[2:], label = 'Prediction', color='r')
plt.plot(y_test[2:], label = 'actual', color='b')
plt.legend(loc='best')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.

# %% [markdown]
# ## 5. 평가지표

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

#Calculate mean absolute error
mae = mean_absolute_error(val_predict[2:],y_test[2:])
print('MAE: %f' % mae)

#Calculate mean squared error and root mean squared error
mse = mean_squared_error(val_predict[2:], y_test[2:])
print('MSE: %f' % mse)
rmse = np.sqrt(mse)
print('RMSE: %f' % rmse)

#Calculate mean_absolute_percentage_error
mape = mean_absolute_percentage_error(val_predict[2:],y_test[2:])
print('MAPE: %f' % mape)
# Out:
# MAE: 58.565098
# MSE: 5774.105456
# RMSE: 75.987535
# MAPE: 0.039698
